# %% [markdown]
# <a href="https://colab.research.google.com/github/emetcalf-vas/Group19_QM2/blob/main/Group19_QM2_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QM2 Group 19 note boook
# lowkey dont know how we want to organize it all but here is kinda a test notebook/ main notebook

# %%
print("goated group")
# Out:
# goated group

# %%
print("loving the vibe here")
# Out:
# loving the vibe here

# %% [markdown]
# ###Throw down libraries that you want to import or install here

# %%
# !pip install openpyxl

# %%
import pandas as pd

# %% [markdown]
# ### Next area could be used for downloading all the data
# Idk how we want to organize it either modually by data set or by step??

# %%
url_annual_LA_emissions = "https://raw.githubusercontent.com/emetcalf-vas/Group19_QM2/main/data/Annual_Certified_Emissions_gte2015.xlsx"

annual_LA_emissions = pd.read_excel(url_annual_LA_emissions, engine= "openpyxl")

annual_LA_emissions
# Out:
#       REPORTING_YEAR  AI_NUMBER  \
# 0               2015         71
# 1               2016         71
# 2               2017         71
# 3               2018         71
# 4               2019         71
# ...              ...        ...
# 6913            2020     242663
# 6914            2021     242663
# 6915            2022     242663
# 6916            2023     242663
# 6917            2023     242670
#
#                                                 AI_NAME PARISH_OR_COUNTY_DESC  \
# 0                         Montpelier Compressor Station            St. Helena
# 1                         Montpelier Compressor Station            Livingston
# 2                         Montpelier Compressor Station            St. Helena
# 3                         Montpelier Compressor Station            St. Helena
# 4                         Montpelier Compressor Station            St. Helena
# ...                                                 ...                   ...
# ...

# %%
annual_LA_emissions.loc[89]
# Out:
# REPORTING_YEAR                                                              2021
# AI_NUMBER                                                                    312
# AI_NAME                        Calumet Cotton Valley Refining LLC - Cotton Va...
# PARISH_OR_COUNTY_DESC                                                    Webster
# PRIMARY_NAICS_CODE                                                        324110
#                                                      ...
# Vinyl chloride - lb                                                          NaN
# Vinylidene chloride - lb                                                     NaN
# VOC, Total - tons                                                      229.02367
# Xylene (mixed isomers) - lb                                                  NaN
# Zinc (and compounds) - lb                                                    NaN
# Name: 89, Length: 176, dtype: object
